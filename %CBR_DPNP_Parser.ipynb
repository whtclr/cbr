# %%
from bs4 import BeautifulSoup
import bs4 as bs
import requests
import numpy as np, pandas as pd

# %%
headings=[]
contents=[]
dict={}
url='http://www.cbr.ru/inside/inside_detect/#y2018'
        #print(url)
page = requests.get(url)
soup = BeautifulSoup(page.content,'html.parser')
tables=soup.find_all('div',{'class':'dropdown'})
for m in tables:
    dropdown_title=m.find('div',{'class':'dropdown_title referenceable'}).get_text()
    dropdown_content=m.find('div',{'class':'dropdown_content'}).get_text()
    print(dropdown_title)
    print(dropdown_content)
# Out:
# Установлены факты манипулирования рынками ряда финансовых инструментов
#
# 26 декабря 2019 года
# ...
